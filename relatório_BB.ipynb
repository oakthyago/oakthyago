# %% [markdown]
# <a href="https://colab.research.google.com/github/oakthyago/oakthyago/blob/main/relat%C3%B3rio_BB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/relatorio-3285.xlsx")

# %%
df.columns
# Out:
# Index(['Prefixo', 'Dependência', 'UF', 'Carteira', 'Tipo da Carteira',
#        'Funcionário', 'Mês', 'Nota', 'Motivos', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
df.head()
# Out:
#    Prefixo Dependência   UF  Carteira           Tipo da Carteira Funcionário  \
# 0      NaN         NaN  NaN       NaN                        NaN         NaN
# 1    446.0    TIMBAUBA   PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
# 2    446.0    TIMBAUBA   PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
# 3    446.0    TIMBAUBA   PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
# 4    446.0    TIMBAUBA   PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
#
#         Mês  Nota                         Motivos  \
# 0       NaN   NaN  Tempo de Atendimento/ \nEspera
# 1  Dezembro   4.0                           False
# 2  Dezembro   5.0                           False
# 3  Dezembro   5.0                            True
# 4  Novembro   5.0                           False
#
#                                Unnamed: 9  \
# 0  Boa Vontade/\nCordialidade/\nInteresse
# 1                                   False
# 2                                   False
# 3                                    True
# 4                                   False
#
#                              Unnamed: 10
# 0  Domínio do Assunto/\nProfissionalismo
# 1                                  False
# 2                                   True
# 3                                   True
# 4                                  False

# %%
True_count = df["Motivos"].value_counts().get(True, 0)
True_count
#Tempo de Atendimento/ \nEspera
# Out:
# 53

# %%
True_count = df["Unnamed: 9"].value_counts().get(True, 0)
True_count
Boa Vontade/\nCordialidade/\nInteresse
# Out:
# 151

# %%
True_count = df["Unnamed: 10"].value_counts().get(True, 0)
True_count
#Domínio do Assunto/\nProfissionalismo
# Out:
# 68

# %%
filtered_df = df[df["Funcionário"] == "F9342321"]

# Calculate True_count for the filtered DataFrame
filtered_df["Motivos"].value_counts().get(True, 0)

#Tempo de Atendimento/ \nEspera
# Out:
# 4

# %%
Nota2=filtered_df["Motivos"].value_counts().get(True, 0)
Percentual2=filtered_df["Motivos"].value_counts().get(True, 0)/len(filtered_df)* 100
print(Nota2)
Percentual2
#Tempo de Atendimento/ \nEspera
# Out:
# 4
# 10.526315789473683

# %%
Nota1=filtered_df["Unnamed: 9"].value_counts().get(True, 0)
Percentual1=filtered_df["Unnamed: 9"].value_counts().get(True, 0)/len(filtered_df)* 100
print(Nota1)
Percentual1
#Boa Vontade/\nCordialidade/\nInteresse
# Out:
# 14
# 36.84210526315789

# %%
Nota=filtered_df["Unnamed: 10"].value_counts().get(True, 0)
Percentual=filtered_df["Unnamed: 10"].value_counts().get(True, 0)/len(filtered_df)* 100
print(Nota)
Percentual
#Boa Vontade/\nCordialidade/\nInteresse
#Domínio do Assunto/\nProfissionalismo
# Out:
# 4
# 10.526315789473683

# %% [markdown]
# Tratar dados

# %%
df.columns
# Out:
# Index(['Prefixo', 'Dependência', 'UF', 'Carteira', 'Tipo da Carteira',
#        'Funcionário', 'Mês', 'Nota', 'Motivos', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
# prompt: rename columns to :
# ['Prefixo', 'Dependência', 'UF', 'Carteira', 'Tipo da Carteira',
#        'Funcionário', 'Mês', 'Nota', 'Tempo de Atendimento Espera', 'Boa Vontade Cordialidade', 'Domínio do Assunto']

import pandas as pd

df = pd.read_excel("/content/relatorio-3285.xlsx")

new_columns = ['Prefixo', 'Dependência', 'UF', 'Carteira', 'Tipo da Carteira',
               'Funcionário', 'Mês', 'Nota', 'Tempo de Atendimento Espera', 'Boa Vontade Cordialidade', 'Domínio do Assunto']

# Check if the number of new columns matches the number of existing columns
if len(new_columns) == len(df.columns):
    df.columns = new_columns
else:
    print("Error: The number of new column names does not match the number of existing columns.")
    # Handle the mismatch appropriately, e.g., add or remove columns

df.head()
# Out:
#    Prefixo Dependência   UF  Carteira           Tipo da Carteira Funcionário  \
# 0      NaN         NaN  NaN       NaN                        NaN         NaN
# 1    446.0    TIMBAUBA   PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
# 2    446.0    TIMBAUBA   PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
# 3    446.0    TIMBAUBA   PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
# 4    446.0    TIMBAUBA   PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
#
#         Mês  Nota     Tempo de Atendimento Espera  \
# 0       NaN   NaN  Tempo de Atendimento/ \nEspera
# 1  Dezembro   4.0                           False
# 2  Dezembro   5.0                           False
# 3  Dezembro   5.0                            True
# 4  Novembro   5.0                           False
#
#                  Boa Vontade Cordialidade  \
# 0  Boa Vontade/\nCordialidade/\nInteresse
# 1                                   False
# 2                                   False
# 3                                    True
# 4                                   False
#
#                       Domínio do Assunto
# 0  Domínio do Assunto/\nProfissionalismo
# 1                                  False
# 2                                   True
# 3                                   True
# 4                                  False

# %%
df = df.drop(0)
df.head()
# Out:
#    Prefixo Dependência  UF  Carteira           Tipo da Carteira Funcionário  \
# 1    446.0    TIMBAUBA  PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
# 2    446.0    TIMBAUBA  PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
# 3    446.0    TIMBAUBA  PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
# 4    446.0    TIMBAUBA  PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
# 5    446.0    TIMBAUBA  PE    7002.0  700 - GRUPOS NEG E INFORM    F9916863
#
#         Mês  Nota Tempo de Atendimento Espera Boa Vontade Cordialidade  \
# 1  Dezembro   4.0                       False                    False
# 2  Dezembro   5.0                       False                    False
# 3  Dezembro   5.0                        True                     True
# 4  Novembro   5.0                       False                    False
# 5  Novembro   5.0                       False                     True
#
#   Domínio do Assunto
# 1              False
# 2               True
# 3               True
# 4              False
# 5               True

# %%
# Get unique employee IDs
unique_employees = df["Funcionário"].unique()

# Create a figure and axes for the plot
fig, ax = plt.subplots()

# Iterate over unique employees and plot data
for employee_id in unique_employees:
    employee_data = df[df["Funcionário"] == employee_id]

    # Assuming your columns are correctly named in the DataFrame
    x = employee_data["Tempo de Atendimento Espera"]
    y1 = employee_data["Boa Vontade Cordialidade"]
    y2 = employee_data["Domínio do Assunto"]

    # You can customize the plot as needed
    # For example, change colors, markers, or line styles
    ax.plot(x, y1, label=f"Employee {employee_id} - Cordialidade", marker='o')
    ax.plot(x, y2, label=f"Employee {employee_id} - Domínio", marker='x')

# Set plot labels and title
ax.set_xlabel("Tempo de Atendimento Espera")
ax.set_ylabel("Values")
ax.set_title("Employee Data")

# Add a legend
ax.legend()

# Show the plot
plt.show()

# %%
unique_employees
# Out:
# array(['F9916863', 'F9476713', 'F9342321', 'F9329466', 'F8620357',
#        'F8030919', 'F5721682', 'F3296093', 'F3295818', 'F2253189',
#        'F1833287', 'F1367519'], dtype=object)
